# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px
import yfinance as yf
import datetime as dt
import plotly.graph_objects as go
from PIL import Image

# %%
data = pd.read_csv("../data/NIFTY-ALPHA-50.csv")
tickers = data['SYMBOL \n'][1:]
tickers
stocks_name = []
for value in tickers:
    stocks_name.append(value+'.NS')
stocks_name
# Out:
# ['RVNL.NS',
#  'SUZLON.NS',
#  'GICRE.NS',
#  'KALYANKJIL.NS',
#  'KEI.NS',
#  'IRFC.NS',
#  'KPITTECH.NS',
#  'ANGELONE.NS',
#  'CYIENT.NS',
#  'APOLLOTYRE.NS',
#  'CUMMINSIND.NS',
#  'RECLTD.NS',
#  'LUPIN.NS',
#  'UNIONBANK.NS',
#  'BHEL.NS',
#  'NHPC.NS',
#  'LODHA.NS',
#  'DIXON.NS',
#  'TVSMOTOR.NS',
#  'PFC.NS',
#  'INDIANB.NS',
#  'OFSS.NS',
#  'AUROPHARMA.NS',
#  'POONAWALLA.NS',
#  'INDHOTEL.NS',
#  'ZYDUSLIFE.NS',
#  'LTF.NS',
#  'NCC.NS',
#  'BAJAJ-AUTO.NS',
#  'HINDCOPPER.NS',
#  'PRESTIGE.NS',
#  'PNB.NS',
#  'GLENMARK.NS',
#  'MCX.NS',
#  'VBL.NS',
#  'ADANIPOWER.NS',
#  'BSOFT.NS',
#  'ADANIGREEN.NS',
#  'CANBK.NS',
#  'ZOMATO.NS',
#  'TRENT.NS',
#  'APARINDS.NS',
#  'ABB.NS',
#  'POLICYBZR.NS',
#  'BEL.NS',
#  'DLF.NS',
#  'HAL.NS',
#  'BSE.NS',
#  'JSL.NS',
#  'SUPREMEIND.NS']

# %%
Image1 = Image.open('../BB/ICICIBANK.png')
Image2 = Image.open('../LR/ICICIBANK.png')
Image3 = Image.open('../MONTHLY_RETURN/ICICBANK.png')
Image4 = Image.open('../SEASONALITY/ICICIBANK.png')
#resize, first image
# Image1 = image1.resize((800, 500))
# image1_size = image1.size
# image2_size = image2.size
# new_image = Image.new('RGB',(2*image1_size[0], image1_size[1]), (250,250,250))
# new_image.paste(image1,(0,0))
# new_image.paste(image2,(image1_size[0],0))
# new_image.save("images/merged_image.jpg","JPEG")
# new_image.show()

new_image = Image.new('RGBA',size=(1200, 2400))
new_image.paste(Image1, (0,0))
new_image.paste(Image2, (0,600))
new_image.paste(Image3, (0,1200))
new_image.paste(Image4, (0,1800))
new_image
# Out:
# <PIL.Image.Image image mode=RGBA size=1200x2400>

# %%
Image1 = Image.open('../BB/ICICIBANK.png')
print(Image1.format, Image1.size)
Image1,
Im2.size
# Out:
# PNG (1200, 600)
# (1200, 400)

# %%
# Out:
# Type:        module
# String form: <module 'PIL.Image' from '/opt/anaconda3/lib/python3.11/site-packages/PIL/Image.py'>
# File:        /opt/anaconda3/lib/python3.11/site-packages/PIL/Image.py
# Docstring:   <no docstring>

# %%
X = np.random.standard_normal(100)
Y = X + 2

# %%
fig = px.scatter(X,Y)
fig

# %%
fig.write_image("../top_50/test.png")

# %%
fig.write_image("test1.jpg")

# %%
import sys
from PIL import Image

images = [Image.open(x) for x in ['test1.jpg', 'test1.jpg', 'test1.jpg']]
widths, heights = zip(*(i.size for i in images))

total_width = max(widths)
max_height = max(heights)

new_im = Image.new('RGB', (total_width, max_height))

x_offset = 0
for im in images:
  new_im.paste(im, (x_offset,0))
  x_offset += im.size[0]

new_im.save('test.jpg')

# %%
new_im
# Out:
# <PIL.Image.Image image mode=RGB size=700x500>

# %%
images
# Out:
# [<PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=700x500>,
#  <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=700x500>,
#  <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=700x500>]

# %%
https://note.nkmk.me/en/python-pillow-concat-images/

# %%
a = {}
a[1] = 1
a
# Out:
# {1: 1}

# %%
import yfinance as yf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pandas.plotting import scatter_matrix

# %%
# get price data from yfinance
company = 'INFY.NS'
start_date = '2014-06-01'
end_date = '2024-08-03'
yf_data = yf.download(company, start=start_date, end = end_date)
yf_data = yf_data.resample('D').ffill()
yf_data = pd.DataFrame(yf_data['Close'])
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
data_p_n_l = pd.read_excel("../../data/Infosys.xlsx", skiprows=15, sheet_name = "Data Sheet", nrows=15)
data_p_n_l = data_p_n_l.T

# update header
new_header = data_p_n_l.iloc[0] #grab the first row for the header
data_p_n_l = data_p_n_l[1:] #take the data less the header row
data_p_n_l.columns = new_header #set the header row as the df header

# %%
data_p_n_l['Date'] = pd.to_datetime(data.index)

data_p_n_l = data_p_n_l.set_index(data['Date'])
data_p_n_l = data_p_n_l.drop(columns=["Date"])
data_p_n_l = data_p_n_l.dropna(axis=1)

# %%
# Add price to the data frame
price = yf_data.loc[data['Date']]['Close']
price.values
data_p_n_l['Close'] = price.values

# %%
data_p_n_l
# Out:
# Report Date     Sales Power and Fuel Other Mfr. Exp Employee Cost  \
# Date
# 2015-03-31    53319.0          219.0         3979.0       29811.0
# 2016-03-31    62441.0          217.0         5860.0       34415.0
# 2017-03-31    68484.0          228.0         6712.0       37669.0
# 2018-03-31    70522.0          207.0         7286.0       38902.0
# 2019-03-31    82675.0          221.0         9902.0       45323.0
# 2020-03-31    90791.0          229.0        11086.0       50895.0
# 2021-03-31   100472.0          143.0        12800.0       55547.0
# 2022-03-31   121641.0          132.0        20690.0       63997.0
# 2023-03-31   146767.0          176.0        26330.0       78374.0
# 2024-03-31   153670.0          199.0        27195.0       82636.0
#
# Report Date Selling and admin Other Expenses Other Income Depreciation  \
# Date
# 2015-03-31             3385.0         1042.0       3430.0       1017.0
# 2016-03-31             4441.0          429.0       3120.0       1459.0
# 2017-03-31             4584.0          687.0       3050.0       1703.0
# 2018-03-31             4585.0          720.0       3311.0       1863.0
# 2019-03-31             5553.0         1506.0       2882.0       2011.0
# 2020-03-31             5375.0          939.0       2803.0       2893.0
# 2021-03-31             3194.0          899.0       2201.0       3267.0
# 2022-03-31             4305.0         1026.0       2295.0       3476.0
# 2023-03-31             5300.0         1457.0       2701.0       4225.0
# 2024-03-31             5705.0         1510.0       4711.0       4678.0
#
# Report Date Profit before tax     Tax Net profit Dividend Amount        Close
# Date
# 2015-03-31            17284.0  4911.0    12372.0          6806.8   554.587524
# 2016-03-31            18740.0  5251.0    13489.0          5548.4   609.150024
# 2017-03-31            19951.0  5598.0    14353.0          5891.6   511.125000
# 2018-03-31            20270.0  4241.0    16029.0          9465.6   565.900024
# 2019-03-31            21041.0  5631.0    15404.0          9222.5   737.799988
# 2020-03-31            22007.0  5368.0    16594.0          7427.0   641.500000
# 2021-03-31            26628.0  7205.0    19351.0         11469.6  1368.050049
# 2022-03-31            30110.0  7964.0    22110.0         13007.6  1906.849976
# 2023-03-31            33322.0  9214.0    24095.0         14069.2  1427.949951
# 2024-03-31            35988.0  9740.0    26233.0         19053.2  1498.050049

# %%
data_p_n_l.columns
# Out:
# Index(['Sales', 'Power and Fuel', 'Other Mfr. Exp', 'Employee Cost',
#        'Selling and admin', 'Other Expenses', 'Other Income', 'Depreciation',
#        'Profit before tax', 'Tax', 'Net profit', 'Dividend Amount', 'Close'],
#       dtype='object', name='Report Date')

# %%
data_p_n_l.dtypes
# Out:
# Report Date
# Sales                 object
# Power and Fuel        object
# Other Mfr. Exp        object
# Employee Cost         object
# Selling and admin     object
# Other Expenses        object
# Other Income          object
# Depreciation          object
# Profit before tax     object
# Tax                   object
# Net profit            object
# Dividend Amount       object
# Close                float64
# dtype: object

# %%
# Problem = create a percentage change for each column and then create a heat map. 
pl = pd.DataFrame()
for col in data_p_n_l:
    # print(col)
    pl[col] = data_p_n_l[col].pct_change()*100

# %%
pl.dropna()
# Out:
#                 Sales  Power and Fuel  Other Mfr. Exp  Employee Cost  \
# Date
# 2016-03-31  17.108348       -0.913242       47.273184      15.443964
# 2017-03-31   9.677936        5.069124       14.539249       9.455179
# 2018-03-31   2.975878       -9.210526        8.551847       3.273249
# 2019-03-31  17.232920        6.763285       35.904474      16.505578
# 2020-03-31   9.816752        3.619910       11.957180      12.293979
# 2021-03-31  10.662951      -37.554585       15.460942       9.140387
# 2022-03-31  21.069552       -7.692308       61.640625      15.212343
# 2023-03-31  20.655864       33.333333       27.259546      22.465116
# 2024-03-31   4.703373       13.068182        3.285226       5.438028
#
#             Selling and admin  Other Expenses  Other Income  Depreciation  \
# Date
# 2016-03-31          31.196455      -58.829175     -9.037901     43.461160
# 2017-03-31           3.219995       60.139860     -2.243590     16.723783
# 2018-03-31           0.021815        4.803493      8.557377      9.395185
# 2019-03-31          21.112323      109.166667    -12.956811      7.944176
# 2020-03-31          -3.205475      -37.649402     -2.741152     43.858777
# 2021-03-31         -40.576744       -4.259851    -21.476989     12.927757
# 2022-03-31          34.783970       14.126808      4.270786      6.397306
# 2023-03-31          23.112660       42.007797     17.690632     21.547756
# 2024-03-31           7.641509        3.637612     74.416883     10.721893
#
#             Profit before tax        Tax  Net profit  Dividend Amount  \
# Date
# 2016-03-31           8.423976   6.923234    9.028451       -18.487395
# 2017-03-31           6.462113   6.608265    6.405219         6.185567
# 2018-03-31           1.598917 -24.240800   11.677001        60.662638
# 2019-03-31           3.803651  32.775289   -3.899183        -2.568247
# 2020-03-31           4.591037  -4.670574    7.725266       -19.468691
# 2021-03-31          20.997864  34.221311   16.614439        54.431130
# 2022-03-31          13.076461  10.534351   14.257661        13.409360
# 2023-03-31          10.667552  15.695630    8.977838         8.161383
# 2024-03-31           8.000720   5.708704    8.873210        35.424900
#
#                  Close
# Date
# 2016-03-31    9.838393
# 2017-03-31  -16.092099
# 2018-03-31   10.716561
# 2019-03-31   30.376384
# 2020-03-31  -13.052316
# 2021-03-31  113.257997
# 2022-03-31   39.384519
# 2023-03-31  -25.114720
# 2024-03-31    4.909142

# %%
sns.color_palette("YlOrBr", as_cmap=True)
sns.heatmap(pl.dropna(), cmap='YlOrRd')
sns.heatmap(pl.dropna(), annot=True, fmt=".1f")
# Out:
# <Axes: ylabel='Date'>

# %%
# correlation 
corr = pl.corr()
corr.style.background_gradient(cmap='coolwarm').format(precision=2)
# Out:
# <style type="text/css">
# #T_65bbe_row0_col0, #T_65bbe_row1_col1, #T_65bbe_row2_col2, #T_65bbe_row3_col3, #T_65bbe_row4_col4, #T_65bbe_row5_col5, #T_65bbe_row6_col6, #T_65bbe_row7_col7, #T_65bbe_row8_col8, #T_65bbe_row9_col9, #T_65bbe_row10_col10, #T_65bbe_row11_col11, #T_65bbe_row12_col12 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_65bbe_row0_col1 {
#   background-color: #f2cbb7;
#   color: #000000;
# }
# #T_65bbe_row0_col2 {
#   background-color: #d65244;
#   color: #f1f1f1;
# }
# #T_65bbe_row0_col3 {
#   background-color: #c32e31;
#   color: #f1f1f1;
# }
# #T_65bbe_row0_col4, #T_65bbe_row9_col8 {
#   background-color: #f59c7d;
#   color: #000000;
# }
# #T_65bbe_row0_col5, #T_65bbe_row1_col0, #T_65bbe_row9_col2 {
#   background-color: #e2dad5;
#   color: #000000;
# }
# #T_65bbe_row0_col6, #T_65bbe_row3_col11 {
#   background-color: #3f53c6;
#   color: #f1f1f1;
# }
# #T_65bbe_row0_col7, #T_65bbe_row2_col9 {
#   background-color: #d4dbe6;
#   color: #000000;
# }
# #T
{
#   background-color: #a2c1ff;
#   color: #000000;
# }
# #T_65bbe_

# %%
corr
# Out:
#                       Sales  Power and Fuel  Other Mfr. Exp  Employee Cost  \
# Sales              1.000000        0.259562        0.858075       0.930781
# Power and Fuel     0.259562        1.000000       -0.009360       0.482733
# Other Mfr. Exp     0.858075       -0.009360        1.000000       0.643398
# Employee Cost      0.930781        0.482733        0.643398       1.000000
# Selling and admin  0.599476        0.623774        0.686174       0.548057
# Other Expenses     0.205830        0.300245        0.028277       0.222632
# Other Income      -0.361214        0.493100       -0.373221      -0.294142
# Depreciation       0.102720        0.165897        0.027638       0.270575
# Profit before tax  0.313538       -0.486105        0.215776       0.171050
# Tax                0.535771       -0.136627        0.308279       0.486590
# Net profit        -0.141804       -0.518090       -0.019239      -0.286724
# Dividend Amount   -0.552461       -0.473690       -0.446151      -0.648775
# Close              0.013404       -0.857605        0.136944      -0.199851
#
#                    Selling and admin  Other Expenses  Other Income  \
# Sales                       0.599476        0.205830     -0.361214
# Power and Fuel              0.623774        0.300245      0.493100
# Other Mfr. Exp              0.686174        0.028277     -0.373221
# Employee Cost               0.548057        0.222632     -0.294142
# Selling and admin           1.000000        0.140173      0.185662
# Other Expenses              0.140173        1.000000     -0.047806
# Other Income                0.185662       -0.047806      1.000000
# Depreciation                0.085341       -0.654870     -0.222406
# Profit before tax          -0.380332       -0.183731     -0.181163
# Tax                        -0.118524        0.424763     -0.300633
# Net profit                 -0.368582       -0.617710      0.043573
# Dividend Amount            -0.562175        0.050439      0.238618
# Close                      -0.541146       -0.055178     -0.386803
#
#                    Depreciation  Profit before tax       Tax  Net profit  \
# Sales                  0.102720           0.313538  0.535771   -0.141804
# Power and Fuel         0.165897          -0.486105 -0.136627   -0.518090
# Other Mfr. Exp         0.027638           0.215776  0.308279   -0.019239
# Employee Cost          0.270575           0.171050  0.486590   -0.286724
# Selling and admin      0.085341          -0.380332 -0.118524   -0.368582
# Other Expenses        -0.654870          -0.183731  0.424763   -0.617710
# Other Income          -0.222406          -0.181163 -0.300633    0.043573
# Depreciation           1.000000          -0.147548 -0.218887   -0.028719
# Profit before tax     -0.147548           1.000000  0.617301    0.638109
# Tax                   -0.218887           0.617301  1.000000   -0.207075
# Net profit            -0.028719           0.638109 -0.207075    1.000000
# Dividend Amount       -0.677150           0.281920 -0.118723    0.522494
# Close                 -0.370640           0.712671  0.543925    0.407917
#
#                    Dividend Amount     Close
# Sales                    -0.552461  0.013404
# Power and Fuel           -0.473690 -0.857605
# Other Mfr. Exp           -0.446151  0.136944
# Employee Cost            -0.648775 -0.199851
# Selling and admin        -0.562175 -0.541146
# Other Expenses            0.050439 -0.055178
# Other Income              0.238618 -0.386803
# Depreciation             -0.677150 -0.370640
# Profit before tax         0.281920  0.712671
# Tax                      -0.118723  0.543925
# Net profit                0.522494  0.407917
# Dividend Amount           1.000000  0.497440
# Close                     0.497440  1.000000

# %%
corr[corr['Close']> 0.7][:-1].index[0]
# Out:
# 'Profit before tax'

# %%
corr['Profit before tax'].values
# Out:
# array([ 0.31353776, -0.48610501,  0.21577585,  0.17104978, -0.38033214,
#        -0.18373101, -0.18116306, -0.14754755,  1.        ,  0.61730102,
#         0.63810866,  0.28192031,  0.7126708 ])

# %%
a = corr[['Close', 'Profit before tax']].values
plt.plot(a)
# Out:
# [<matplotlib.lines.Line2D at 0x18143b6d0>,
#  <matplotlib.lines.Line2D at 0x18143b0d0>]

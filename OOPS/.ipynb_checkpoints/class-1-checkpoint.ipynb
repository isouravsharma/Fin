# %%
# this is to learn the OOPS concept by creating the class

# %%
import yfinance as yf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
class Data_yfinance:
    """This class with get the data from the source - yfinance"""
    def __init__(self, ticker, years):
        self.ticker = ticker
        self.years = years
        
    def download_data(self):    
        data = yf.download(tickers=self.ticker, period=self.years)
        return data['Close']

# %%
bank = get_data_yfinance('TATAPOWER.NS','5y')
df = bank.download_data()
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
class Return:
    """This class calculate the return of ticker"""
    def __init__(self, data):
        self.data = data

    def calculate_week_return(self):
        return self.data.resample('W').ffill().pct_change()*100

# %%
week = Return(df)

# %%
# df.resample('W').ffill().pct_change()*100
week.calculate_week_return()
# Out:
# Date
# 2019-07-14         NaN
# 2019-07-21   -2.347760
# 2019-07-28   -6.386181
# 2019-08-04   -5.056176
# 2019-08-11   -2.789521
#                 ...
# 2024-06-16    1.149815
# 2024-06-23   -2.217760
# 2024-06-30    0.433096
# 2024-07-07   -0.147525
# 2024-07-14   -0.545522
# Freq: W-SUN, Name: Close, Length: 262, dtype: float64

# %%
plt.plot(week.calculate_week_return())
plt.axhline(0, color = 'red')
plt.axhline(2*np.std(week.calculate_week_return()))
plt.axhline(-2*np.std(week.calculate_week_return()))
